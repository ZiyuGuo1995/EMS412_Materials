# %% [markdown]
# # Week-8 Statics: Forces and Moments

# %% [markdown]
# # 1. Vectors

# %% [markdown]
# To creat vectors, we will use "array" in Python.
#
# What is array?
# An array is a special variable, which can hold more than one value at a time.
#
# Single dimensional arrays are created in python by importing an array module. The multi-dimensional arrays cannot be created with the array module implementation. Vectors are created using the import array class.

# %%
import numpy as np
from math import * # Import all the math functions from the math library
from numpy import array

# %% [markdown]
# ## 1.1 create a 2D vector

# %%
force2D=array([1, 5]) ## Two values to represent the two dimensions
print(force2D)
# Out:
# [1 5]

# %% [markdown]
# In python list or array,  list index starts with 0 in Python

# %%
force2D[0]
# Out:
# 1

# %%
force2D[1]
# Out:
# 5

# %% [markdown]
# force2D[2] will introduce error, as index 2 is out of bound for axis 0 with size 2, the list only has 2 values, to call them, you can only start from force2D[0] and force2D[1]

# %%
## example of index error 
# Try to uncomment this line below
# force2D[2]

# %% [markdown]
# ## 1.2 create a 3D vector

# %%
force3D= array([1, 5, 6]) # Only has one more value in the array to represent the 3rd dimension
print(force3D)
# Out:
# [1 5 6]

# %% [markdown]
# # 2. Vector operations

# %% [markdown]
# Various operations are performed over vectors. Some of the operations include basic addition, subtraction, multiplication, division. Some other operations include dot product and cross product of two vectors.

# %% [markdown]
# ## 2.1 Multiplication of a Python vector with a scalar

# %%
a= array([1,2,3]) # A vector
print(a)
s= 2.0 # A scalar
print(s)
c=s*a # The product of a vector and a scalar
print(c)
# Out:
# [1 2 3]
# 2.0
# [2. 4. 6.]

# %% [markdown]
# ## 2.2 Addition of vectors

# %% [markdown]
# Fistly, the final vector’s length is the same as the two parents’ vectors. Each element of the new vector is the sum of the two vectors. NumPy allows compact and direct addition of two vectors. Without using the NumPy array, the code becomes hectic.

# %%
x=array([1,5,6])
print(x)
y=array([1,5,6])
print(y)
z=x+y
print(z)
# Out:
# [1 5 6]
# [1 5 6]
# [ 2 10 12]

# %% [markdown]
# ## 2.3 what if x, y are scalars?

# %%
x=[1,5,6]
print(x)
y=[1,5,6]
print(y)
z=x+y
print(z)
# Out:
# [1, 5, 6]
# [1, 5, 6]
# [1, 5, 6, 1, 5, 6]

# %% [markdown]
# Compare the addition of vectors and scalars, you will find z=[2 10 12] is a vector, while z=[1, 5, 6, 1, 5, 6] is a scalar.

# %% [markdown]
# ## 2.4 Subtraction of vectors

# %%
x=array([1,5,6])
print(x)
y=array([1,4,6])
print(y)
z=x-y
print(z)
# Out:
# [1 5 6]
# [1 4 6]
# [0 1 0]

# %% [markdown]
# ## Example 1:
#
# Calculate the resultant of two forces acting on the hook:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Construct the force vectors:

# %%
# We choose the horizontal and vertical axis as the coordinate system

# Your code #

# %% [markdown]
# Now, calculate the resultant force:

# %%
#Your code#

# %%
import numpy as np
from math import * # Import all the math functions from the math library
from numpy import array
#solution#
F1=array([100*cos(15*pi/180),100*sin(15*pi/180)])
F2=array([150*sin(10*pi/180),150*cos(10*pi/180)])
FR=F1+F2
FR_norm=mag1(FR)
print('The resultant force vector is', FR)
print('The magnitude of the resultant force vector is', FR_norm)
# Out:
# The resultant force vector is [122.63980928 173.60306746]
# The magnitude of the resultant force vector is 212.55245905945424

# %% [markdown]
# ## 2.5 Vector dot product
# Dot product calculates the sum of the two vectors’ multiplied elements. Dot Product returns a scalar number as a result. The dot product is useful in calculating the projection of vectors. Dot product in Python also determines orthogonality and vector decompositions.
#
# The dot product of two vectors a = [a1, a2, …, an] and b = [b1, b2, …, bn] is defined as:
#
# ${\displaystyle \mathbf {\color {red}a} \cdot \mathbf {\color {blue}b} =\sum _{i=1}^{n}{\color {red}a}_{i}{\color {blue}b}_{i}={\color {red}a}_{1}{\color {blue}b}_{1}+{\color {red}a}_{2}{\color {blue}b}_{2}+\cdots +{\color {red}a}_{n}{\color {blue}b}_{n}}{\displaystyle \mathbf {\color {red}a} \cdot \mathbf {\color {blue}b} =\sum _{i=1}^{n}{\color {red}a}_{i}{\color {blue}b}_{i}={\color {red}a}_{1}{\color {blue}b}_{1}+{\color {red}a}_{2}{\color {blue}b}_{2}+\cdots +{\color {red}a}_{n}{\color {blue}b}_{n}}$

# %%
x=array([1,5,6])
print(x)
y=array([1,4,6])
print(y)
z=x.dot(y)
print('The dot product of a and b is a scalar:',  z)
# Out:
# [1 5 6]
# [1 4 6]
# The dot product of a and b is a scalar: 57

# %% [markdown]
# Now we can use the **dot product** to calculate the projection of force vectors on a particular axis. We use the force vector in the **Example 1**.

# %%
# Projection on the x-axis
ex=array([1,0]) # Basis vector for x-axis
Fx=FR.dot(ex)
print('The projection of force vector on the x axis is',Fx)
# Out:
# The projection of force vector on the x axis is 122.63980927894637

# %% [markdown]
# Now **your code** to calculate the projection of force vector on the y axis.

# %%
# Projection on the y-axis
## Your code ##

# %% [markdown]
# ## 2.6 Cross product

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Python Vector Cross product works in the same way as the normal cross product. A cross vector is defined as a vector that is perpendicular to these two vectors with a magnitude equal to **the area of the parallelogram spanned by both vectors**. As of now, the vector object honest has a cross multiplication method like that of a dot.
#
# $${\bf{a}} \times {\bf{b}} = \left\| {\bf{a}} \right\|\left\| {\bf{b}} \right\|\sin (\theta )\;{\bf{n}}$$
#
# The cross product can also be expressed as the formal determinant:
#
# ${\displaystyle \mathbf {a\times b} ={\begin{vmatrix}\mathbf {i} &\mathbf {j} &\mathbf {k} \\a_{1}&a_{2}&a_{3}\\b_{1}&b_{2}&b_{3}\\\end{vmatrix}}}$
#
# This determinant can be computed using Sarrus's rule or cofactor expansion. Following the diagonal lines, we have six terms in total.
#
# ![image-3.png](attachment:image-3.png)
#
# Using Sarrus's rule, it expands to
#
# ${\displaystyle {\begin{aligned}\mathbf {a\times b} &=(a_{2}b_{3}\mathbf {i} +a_{3}b_{1}\mathbf {j} +a_{1}b_{2}\mathbf {k} )-(a_{3}b_{2}\mathbf {i} +a_{1}b_{3}\mathbf {j} +a_{2}b_{1}\mathbf {k} )\\&=(a_{2}b_{3}-a_{3}b_{2})\mathbf {i} +(a_{3}b_{1}-a_{1}b_{3})\mathbf {j} +(a_{1}b_{2}-a_{2}b_{1})\mathbf {k} .\end{aligned}}}$
#
# Using cofactor expansion along the first row instead, it expands to
#
# ${\displaystyle {\begin{aligned}\mathbf {a\times b} &={\begin{vmatrix}a_{2}&a_{3}\\b_{2}&b_{3}\end{vmatrix}}\mathbf {i} -{\begin{vmatrix}a_{1}&a_{3}\\b_{1}&b_{3}\end{vmatrix}}\mathbf {j} +{\begin{vmatrix}a_{1}&a_{2}\\b_{1}&b_{2}\end{vmatrix}}\mathbf {k} \\&=(a_{2}b_{3}-a_{3}b_{2})\mathbf {i} -(a_{1}b_{3}-a_{3}b_{1})\mathbf {j} +(a_{1}b_{2}-a_{2}b_{1})\mathbf {k} ,\end{aligned}}}$
#
# which gives the components of the resulting vector directly.

# %%
x=array([1,5,6])
print(x)
y=array([1,4,6])
print(y)
z=np.cross(x,y)
print(z)
# Out:
# [1 5 6]
# [1 4 6]
# [ 6  0 -1]

# %% [markdown]
# Cross Product returns a vector that is perpendicular to both vectors. Firstly, we start by importing the numpy module and array class from it. Nextly, we initialize two arrays with different values. As a cross product of the same vector gives a zero vector, we have to use two different vectors.
#
# **The cross-product is very useful to calculte the moment!** See the example 2 and example 3 in the following section.

# %% [markdown]
# # 3. Plot the force vectors

# %% [markdown]
# ## Visualise the force vector in 2D

# %% [markdown]
# First of all, import the plotting package called "matplotlib.pyplot", use a short form "plt"

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Then define the vectors using arrays

# %%
u = array([3, 1])
v = array([1, 2])
q = u+v
print(q)
# Out:
# [4 3]

# %%
# Plot the figure to visualise the force vectors
fig = plt.figure()  # This is to assign the figure() function to a fig
ax = plt.axes() # This is to assign the axes() function to a simple form ax
start=[0, 0]  # This is the origin point for the arrow
# The arrow function will use the coordinate (x,y) of start point and the vectors
ax.arrow(start[0],start[1], u[0], u[1], head_width=0.05, head_length=0.1, fc='b', ec='b') # Vector u
ax.arrow(start[0],start[1], v[0], v[1], head_width=0.05, head_length=0.1, fc='k', ec='k') # Vector v
ax.arrow(start[0],start[1], q[0], q[1], head_width=0.05, head_length=0.1, fc='r', ec='r') # Resultant Vector q
plt.show()

# %% [markdown]
# Now, it is your turn to change the force vectors in **Example 1** and plot them in a figure as above.

# %%
## Force vectors in example 1###


### Plot the figure####

# %% [markdown]
# # 4. Calculate the moment

# %% [markdown]
# Now let's recap the defintion of moment:
#
# $$  \mathbf{M} = \mathbf{r} \times \mathbf{F}$$
#
# $\mathbf{r}$ is the position vector, while the $\mathbf{F}$ is the force vector

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exmaple 2: a 3D problem

# %% [markdown]
# Question 1:  The position vector is given as $\mathbf{r}= 4 \mathbf{i} + 5\mathbf{j}+ 3\mathbf{k}$ , while the force vector is $\mathbf{F}= -100 \mathbf{i} + 130\mathbf{j}+ 175\mathbf{k}$. Calculate the Moment $\mathbf{M}$.

# %% [markdown]
# ### Method 1: use the cross product equation:

# %% [markdown]
# \begin{equation*}
# \mathbf {M= a\times b} =(a_{2}b_{3}-a_{3}b_{2})\mathbf {i} -(a_{1}b_{3}-a_{3}b_{1})\mathbf {j} +(a_{1}b_{2}-a_{2}b_{1})\mathbf {k}
# \label{eq:cross product1} \tag{1}
# \end{equation*}

# %% [markdown]
# In this case, replacing $\mathbf{a}$ and $\mathbf{b}$ by $\mathbf{r}$ and $\mathbf{F}$ respectively,

# %% [markdown]
# \begin{equation*}
# \mathbf {M=r\times F} =(r_{2}F_{3}-r_{3}F_{2})\mathbf {i} -(r_{1}F_{3}-r_{3}F_{1})\mathbf {j} +(r_{1}F_{2}-r_{2}F_{1})\mathbf {k}
# \label{eq:cross product2} \tag{2}
# \end{equation*}

# %%
# Form the vectors
import numpy as np
r=[4, 5, 3]
F=[-100, 130, 175]
M=np.zeros(3) # This will generate an empty array [0, 0, 0]
M[0]=r[1]*F[2]-r[2]*F[1] # Bear in mind, the first value start r[0], then r[1], r[2]
M[1]=-(r[0]*F[2]-r[2]*F[0])
M[2]=r[0]*F[1]-r[1]*F[0]
print(M)
# Out:
# [  485. -1000.  1020.]

# %% [markdown]
# #### Can you define your own function of cross product according to Equation (2)?

# %%
def crossproduct(r, F):
    ##  Your code ###
    
    
    return M

# %%
## Example code
def crossproduct(r, F):
    M1=r[1]*F[2]-r[2]*F[1] # Bear in mind, the first value start r[0]
    M2=-(r[0]*F[2]-r[2]*F[0])
    M3=r[0]*F[1]-r[1]*F[0]
    M=[M1, M2, M3]
    return M

# %%
r=[4, 5, 3]
F=[-100, 130, 175]
crossproduct(r, F)
# Out:
# [485, -1000, 1020]

# %% [markdown]
# ### Method 2: use the cross product library from numpy (np.cross(x,y))

# %%
# Form the vectors
r=[4, 5, 3]
F=[-100, 130, 175]
M=np.cross(r,F)
print(M)
# Out:
# [  485 -1000  1020]

# %% [markdown]
# ## Example 3:
#
# Determine the 2D moment with respect to Point A  due to the force $F_B$?
#
# Hints (construct the force and position vectors. Their values in out-of-plane $\mathbf{k}$ direction are zeros)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Method 1: use the cross product equation:

# %% [markdown]
# For the equation (2), now $r_{3}$ and $F_{3}$ are zero. We have the moment as:

# %% [markdown]
# \begin{equation*}
# {{\begin{aligned}\mathbf {M= r\times F} &=(r_{2}F_{3}-r_{3}F_{2})\mathbf {i} -(r_{1}F_{3}-r_{3}F_{1})\mathbf {j} +(r_{1}F_{2}-r_{2}F_{1})\mathbf {k} \end{aligned}}}=(r_{1}F_{2}-r_{2}F_{1})\mathbf {k}
# \label{eq:cross product2} \tag{3}
# \end{equation*}

# %%
from math import * # Import all math library
alpha=36.87*pi/180 # convert the degree to rad
# Form the vectors, you need to project the Force vector to a coordiante system x-y (horizontal and vertical directions)
r=[3,0,0]
F=[-50*sin(alpha),-50*cos(alpha),0 ]
M=np.zeros(3) # This will generate an empty array [0, 0, 0]
print("The force vector is :", F)
## Calculate the moment use the equation above

#Your code####

print("The moment vector is :", M)

## Your code to plot the figure ##
# Out:
# The force vector is : [-30.000071456633126, -39.999946407425426, 0]
# The moment vector is : [0. 0. 0.]

# %% [markdown]
# ### Solution

# %%
# Solution
M[0]=0
M[1]=0
M[2]=r[0]*F[1]-r[1]*F[0] # This resemble the equation (3)
print("The force vector is :", F)
print("The moment vector is :", M)


# Plot 2D figure
fig = plt.figure()
ax = plt.axes()
start=[0, 0]
ax.arrow(start[0],start[1], r[0], r[1], head_width=1, head_length=5, fc='b', ec='b') # Vector u
ax.arrow(start[0],start[1], F[0], F[1], head_width=1, head_length=5, fc='k', ec='k') # Vector v
# The moment vector will be an out-of-plane vector
plt.show()
# Out:
# The force vector is : [-30.000071456633126, -39.999946407425426, 0]
# The moment vector is : [   0.            0.         -119.99983922]

# %% [markdown]
# ### Method 2: use the cross product library from numpy (np.cross(x,y)) to solve the example 3

# %%
# Your code #
## Define the force and position vectors

## Then use the cross-product from the numpy library
