# %% [markdown]
# # Problem solving sheet

# %% [markdown]
# ## Q1: Exercise on the mid-point rule

# %% [markdown]
# Compute by hand the area composed of two rectangles (of equal width) that approximates the integral $f(x)$ below. Make a test function that calls the midpoint function in midpoint.py and compares the return value with the hand-calculated value.

# %% [markdown]
# $f(x)=\int _1^3 2x^3dx$

# %% [markdown]
# ### Your code below

# %%
## Your computed value by hand

# %%
## Your own Integration function, check the tutorial to see how you can do it

# %%
## Test the function

# %%
## Error analysis

# %% [markdown]
# ## Q2: Use the numerical integration to tackle some complex functions

# %% [markdown]
# In the 1st active sessions of week 4, Andrew asked you to integrate a function analyatically in Q5. It turns out to be impossible to integrate by hand.
#
# Now we have the numerical integration tool, let's have a crack on this problem.
#
# Find the definite integral of
#
# $$\int_0^2 {\sin (x){e^{{x^2}\cos (x)}}dx} $$
#
# using the mid-point rule.

# %%
## Your code ##

# %% [markdown]
# ## Q3: Numerical integration using the Trapezoidal Rule

# %% [markdown]
# We can also approximate the value of a definite integral by using trapezoids rather than rectangles. In Figure below , the area beneath the curve is approximated by trapezoids rather than by rectangles.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The trapezoidal rule for estimating definite integrals uses trapezoids rather than rectangles to approximate the area under a curve. To gain insight into the final form of the rule, consider the trapezoids shown in Figure above. We assume that the length of each subinterval is given by  Δx . First, recall that the area of a trapezoid with a height of  h  and bases of length  b1  and  b2  is given by  Area=0.5*h(b1+b2) . We see that the first trapezoid has a height  Δx  and parallel bases of length  f(x0)  and  f(x1).
#
# To calculate a trapezium:
#
# ![image-2.png](attachment:image-2.png)
#
# For a single Trapzezium in the above figure, the area is ${\frac {1}{2}} \Delta x_{n} (f(x_{n-1})+f(x_{n}))$
#
# Thus, the area of the first trapezoid in the above Figure is.

# %% [markdown]
# Let ${\displaystyle \{x_{n}\}}$ be a partition of ${\displaystyle [a,b]}$ such that ${\displaystyle a=x_{0}<x_{1}<\cdots <x_{n-1}<x_{n}=b}$ and ${\displaystyle \Delta x_{n}}$
# be the length of the n-th subinterval (that is, ${\displaystyle \Delta x_{n}=x_{n}-x_{n-1}}$), then
#
# ${\displaystyle \int _{a}^{b}f(x)\,dx\approx \sum _{n=1}^{N}{\frac {f(x_{n-1})+f(x_{n})}{2}}\Delta x_{n}={\tfrac {\Delta x}{2}}\left(f(x_{0})+2f(x_{1})+2f(x_{2})+2f(x_{3})+2f(x_{4})+\cdots +2f(x_{n-1})+f(x_{n})\right).}$

# %% [markdown]
# ## Try yourself to implement it

# %% [markdown]
# The function to integrate is $\int _a^b x^2 dx$.

# %% [markdown]
# ### Hint: you need to implement the equation below, sum up all the $f(x_i)$ terms
#
# ${\displaystyle \int _{a}^{b}f(x)\,dx\approx {\tfrac {\Delta x}{2}}\left(f(x_{0})+2f(x_{1})+2f(x_{2})+2f(x_{3})+2f(x_{4})+\cdots +2f(x_{n-1})+f(x_{n})\right).}$

# %%
def InterageTrapz(N, a, b):
    def f(x):
        ## Type your function after the return
        f=  ## the function to be integrated
        return f
    value=0
    value2=0
    dx=(b-a)/N # delta x, the interval length
    value = value + a + b # f(x_0)=a, f(x_n)=b, add the first and last value
    
    for n in range (1, N): # This will iterate number from x_1 to x_(N-1), as the last value has been caculated
        ## Your code ## 
        ### Begin ###

        ### End ###
    value2 = value*dx/2
    return value2
# Out:
#   File "<ipython-input-4-125c8595a82d>", line 14
#     value2 = value*dx/2
#     ^
# IndentationError: expected an indented block

# %%
# Test your code

# %%
N=20 ## interation number
a=0 ## lower bound for integration
b=10 ## upper bound for intergration
print ("Here is your answer using Trapzoidal rule")
print (InterageTrapz (N, a, b))

# %% [markdown]
# Our basic integration program has the inconvenience of depending on the number of trapeziums that we have to change manually. As a basic rule, if we double the number of trapeziums and get the same answer within 0.01, the answer is probably correct.

# %% [markdown]
# ## Q4: Define a program to find:
#
# ## How many trapeziums are needed to get a relative error of less than 0.1?
#
# We can do this use a **for loop** functions or **While** function. Your target is the relative error and you gradullay add up the trapeziums number. Note that it might take a long time to run.
#
# #### Check the function below
# $ f(x)=\int _0^{10} x^2dx = \left [ \frac{1}{2}x^4 \right ]_{0}^{10} = \frac{1}{3}\left [(10)^3 -(0)^3 \right ] \approx 333.33 $

# %%
#Your code

# %% [markdown]
# # Q5: Use the numerical integration for calculating the 1st moment of area

# %% [markdown]
# A filled semicircle with respect to an axis collinear with the base, use the numerical integration to calculate the 1st moment of area $Q_x$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Equation of a semicircle
# $ x^2 + y^2 = r^2$
#
# Step 1: You need to think how to form the integration on this particular shape
#
# ${\displaystyle Q_{x}=\int _{A}ydA}$
#
# How do you express the dA?

# %% [markdown]
# Write the integration equation here, if you know latex code, if not just write it on your paper. You can copy the latex code for the equation using the online tools: https://www.hostmath.com/
#
# **Equation for this work**:
#
# ************** Write your equation here!!!********************* (click this box and you will be able to edit it)
#
# $Q_x=$

# %% [markdown]
# Step 2: once you have the equation, now you can use the numerical integration method to do the caculation and compare with analytical solution.

# %%
## Your code for the exact solution##

# %%
## Your code for the numerical integration using mid-point rule##

# %%
## Your code for the numerical integration using trapeziums rule##
