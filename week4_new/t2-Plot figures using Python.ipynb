# %% [markdown]
# # Plot figures in Python

# %% [markdown]
# **Matplotlib** is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
# The full tutorials can be found from here: https://matplotlib.org/stable/plot_types/index.html

# %% [markdown]
# ## 1.1 Line plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 10), xticks=np.arange(0, 10,1),
       ylim=(0, 8), yticks=np.arange(0, 10,1))

ax.set_xlabel('X') # Axis Title
ax.set_ylabel('Y') # Axis Title

plt.show()

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Based on the example above, can you draw a linear function $y=5x+3$ with $x$ ranging from 0 to 10?

# %%
### Your code below

import matplotlib.pyplot as plt
import numpy as np

# make data
x = np.linspace(0, 10, 100)
y = 5*x+3

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 10), xticks=np.arange(1, 10,1 ),
       ylim=(0, 60), yticks=np.arange(0, 60,10))

ax.set_xlabel('X') # Axis Title
ax.set_ylabel('Y') # Axis Title

plt.show()

# %% [markdown]
# ## 1.2 Bar chart

# %%
import matplotlib.pyplot as plt
import numpy as np

# make data:
np.random.seed(3)
x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))

# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

ax.set_xlabel('X') # Axis Title
ax.set_ylabel('Y') # Axis Title

plt.show()

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# Based on the example above, draw a vertical bar graph based on the following data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
### Your code below
# Hint: the data for X axis or Y axis can be a list

import matplotlib.pyplot as plt
import numpy as np

# make data:
np.random.seed(3)
x = ["Onida", "Sony","Omega", "Jolly", "Prince"]
y = [250,300,150,200,100]

# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)


ax.set_xlabel('Brand of TV') # Axis Title
ax.set_ylabel('Nubmer of sets manufactured per day') # Axis Title

plt.show()
