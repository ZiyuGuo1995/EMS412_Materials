# %% [markdown]
# ## Question 1

# %% [markdown]
# A fixed beam is subjected to a uniformly-distributed load with an intensity of $f=$ 10 N/mm length of $L=$ 200 mm. Now plot its internal shear force and moment diagram.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 1. Define the paramters

# %%
#Program to compute and graph a cantilever beam
#subject to Uniformly Distributed Load

import numpy as np
import matplotlib.pyplot as plt

### Your codes #### 

# define L and f

# %% [markdown]
# ### 2. Find the support reaction forces at point B

# %%
### Your codes####

# %% [markdown]
# ### 3. Do the Cut and find the expression

# %%
#Shear and Bending arrays
x=np.linspace(0,L)


### Your codes####

# Equation for V
V=

# Equation for M
M=



# Find the minimum values for V and M

minV=

minM=

# %% [markdown]
# ### 4. Plot the diagram (use the template below)

# %%
#Diagrams plot
textstr1 = 'min=%.2f (N)'%(minV)
textstr2 = 'min=%.2f (N*mm)'%(minM)
props = dict(boxstyle='round', facecolor='white')


fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(10, 6))

# fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(10, 6))

ax1.fill_between(x, 0, V, facecolor='#377EB8', alpha=0.8)
ax1.set_ylabel('Shear force (N)')
ax1.text(0.78, 0.9, textstr1, transform=ax1.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
ax1.set_title('Cantilever Beam Subjected to Gravity Load')
ax1.grid (True)

ax2.fill_between(x, 0, M, facecolor='#55BA87', alpha=0.8)
ax2.set_ylabel('Moment (N*mm)')
ax2.text(0.68, 0.2, textstr2, transform=ax2.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
ax2.grid (True)

plt.show()
#plt.savefig('beam.pdf', format='svg', dpi=1200)
