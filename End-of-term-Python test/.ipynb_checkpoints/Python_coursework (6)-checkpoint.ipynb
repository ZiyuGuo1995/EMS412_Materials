# %% [markdown]
# # 2022/2023 EMS412U- Computational and Mathematical Modelling 1
#
# ## Python coursework (40% of module)
#
# ## Answer all the 9 questions in this coursework. The total mark is 50.
#
# ### Important things to remember:
# 1. Only fill your codes in the area **"YOUR CODE HERE"**.
# 2. DO NOT change the **predefined contents** in the coding boxes, like the function name, etc.
# 3. DO NOT delete or add any coding boxes, as this will affect the marking system.
# 4. Always use the **print (function(a,b,c))** below the predefined function to output the results and check your codes.
# 5. **You are supposed to work independently and any academic misconduct should be avoided.**
# 6. Some **method marks** will be given to partially-correct answers, so try to fill in something in the coding boxes.
# 7. Read the **instruction** in the **questions** and also in the **coding boxes** for hints!
# 7. You can submit your codes multiple times before the **deadline: 23:59, 16 December 2022**. Only the last version will be marked. **Any late submission is not allowed!**

# %% [markdown]
# # Q1:
# ### [4 marks]
#
# One way to generate the value of Eulers number $e$ is given by the formula
#
# $$ e = \lim_{n\rightarrow \infty} (1+\frac{1}{n})^n $$ .
#
# Complete the code that calculates **the expression inside the limit, that is, $(1+\frac{1}{n})^n$, for some value $n$**.

# %%
# complete the function with the variable "n" and return the value as the variable named "e
# Don't define value of "n" directly inside the function, this should be an input value whe
# For example, approximate_e(1), the same rule applies for the rest of questions!
def approximate_e(n):
    ## DO NOT give any values to "n" inside the function
    ### BEGIN SOLUTION
    e = (1+1/n)**(n)
    ### END SOLUTION
    return e

## Example to check your code ##
n=3## give a random value to n for validation
print(approximate_e(n)) # Print the values and make your judgement
# Out:
# 2.37037037037037

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# marks to check there is some number is returned, even if wrong.
assert type(approximate_e(5)) == float or type(approximate_e(5)) == int
#print( type(approximate_e(5)) == float or type(approximate_e(5)) == int )
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# marks to generate the correct answer
assert abs(approximate_e(5) - 2.4883199999999994) <= 1.e-3
assert abs(approximate_e(10) - 2.5937424601000023) <= 1.e-4
### END HIDDEN TESTS
# Out:
# 48828124.0

# %% [markdown]
# # Q2:
# ### [4.5 marks]
#
# Complete the function that calculates the **sum** of the first $\textbf{ n+1}$ terms of the geometric series
# $$ a , ar, ar^2 ar^3 , ar^4 \ldots ar^{n} $$
# Note that the series begins with $a$ and the last term is $ar^{n}$, in total there are $\textbf{ n+1}$ terms.

# %%
# complete the function given the variables a,r,n and return the value as series_sum.
def sum_geometric_series(a,r,n):
    ### BEGIN SOLUTION
    #series_sum = a*(1-r**(n+1))/(1-r)
    series_sum=0
    for i in range(n+1):
        series_sum = series_sum + a*r**i
    ### END SOLUTION
    return series_sum

print(sum_geometric_series(4, 5,10))
# Out:
# 48828124

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
#marks to check there is some number is returned, even if wrong.
#assert type(sum_geometric_series(4,5,10)) == float or type(sum_geometric_series(5,2,5)) == int
### END HIDDEN TESTS
def function_f(x):
    # YOUR CODE HERE
    #fval = 1 if x in range(-1, 2) else 0
    fval= -1<x<2
    return fval
function_f(-2)
# Out:
# 0

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# marks to check the code gives the correct solution
assert abs(sum_geometric_series(2.0, 2, 10) - 4094 ) < 1.e-3
assert abs(sum_geometric_series(4.0, 5, 10) - 48828124) < 1.e-3
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
## Partially correct, use "n" instead of "n+1" [1 marks].
# marks to check the code gives the correct solution
assert abs(sum_geometric_series(2.0, 2, 10) - 2046.0 ) < 1.e-3
assert abs(sum_geometric_series(4.0, 5, 10) - 9765624.0) < 1.e-3
### END HIDDEN TESTS
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [10], in <cell line: 5>()
#       1 ## Don't write any code in this box
#       2 ### BEGIN HIDDEN TESTS
#       3 ## Partially correct
#       4 # marks to check the code gives the correct solution
# ----> 5 assert abs(sum_geometric_series(2.0, 2, 10) - 2046.0 ) < 1.e-3
#       6 assert abs(sum_geometric_series(4.0, 5, 10) - 9765624.0) < 1.e-3
#
# AssertionError:

# %% [markdown]
# # Q3:
#
# ### [4.5 marks]
#
# Complete the code that returns the value of $f(x)$, which has the value 1 inside the range $-1 \le  x \le 1 $ otherwise it is the value 0.
#
# $$f(x) =
#     \begin{cases}
# 1 ,  \ \ \ x \in [-1,1] \\
# 0 , \ \ \ \text{otherwise}
#     \end{cases}
# $$

# %%
# complete the function to return the value of f(x) given x.
# return as the value called variable "fval"
def function_f(x):
    ### BEGIN SOLUTION
    fval = 0
    if x >= -1 and x <= 1 :
        fval = 1
    ### END SOLUTION
    return fval

## Check your code below using print command

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# marks to check there is some number is returned, even if wrong.
#assert type(function_f(10)) == float or type(function_f(10)) == int
### END HIDDEN TESTS
def function_f(x):
    # YOUR CODE HERE
    if x in range(-1,2):
        fval = 1
    else:
        fval = 0
    return fval


n = function_f(0.5)
print(n)
# Out:
# 0

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark to check value below -1
#assert abs(function_f(-5) - 0) < 1.e-5 
### END HIDDEN TESTS
# complete the function to return the value of f(x) given x.
# return as the value called variable "fval"
def function_f(x):
    # YOUR CODE HERE
    if x in range(-1,2):
        fval = 1
    else:
        fval = 0
    return fval
x = -0.5

    
print (function_f(x))
# Out:
# 0

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark to check value above 1
assert abs(function_f(5) - 0) < 1.e-5 
### END HIDDEN TESTS
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Input In [25], in <cell line: 14>()
#      12      return function_f(x)
#      13 x=0.5
# ---> 14 function_f(x)
#
# Input In [25], in function_f(x)
#       6 def function_f(x):
#       7     # YOUR CODE HERE
# ----> 8     function_f(x)==0
#       9     if -1<=x<=1 :
#      10        print(1)
#
# Input In [25], in function_f(x)
#       6 def function_f(x):
#       7     # YOUR CODE HERE
# ----> 8     function_f(x)==0
#       9     if -1<=x<=1 :
#      10        print(1)
#
#     [... skipping similar frames: function_f at line 8 (2970 times)]
#
# Input In [25], in function_f(x)
#       6 def function_f(x):
#       7     # YOUR CODE HERE
# ----> 8     function_f(x)==0
#       9     if -1<=x<=1 :
#      10        print(1)
#
# RecursionError: maximum recursion depth exceeded

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark to check value inside the range [-1,1]
assert abs(function_f(0) - 1) < 1.e-5 
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark to check value on the limits
assert abs(function_f(1) - 1) < 1.e-5 
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark to check value on the limits
assert abs(function_f(-1) - 1) < 1.e-5 
### END HIDDEN TESTS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       1 ## Don't write any code in this box
#       2 ### BEGIN HIDDEN TESTS
#       3 # mark to check value on the limits
# ----> 4 assert abs(function_f(-1) - 1) < 1.e-5
#
# NameError: name 'function_f' is not defined

# %% [markdown]
# # Q4:
#
# ### [4 marks]
#
# Complete the function that adds 3 matrices together. The matrices will be numpy type and of the same dimension of $3 \times 3$. There are several ways to do this, any correct answer will be accepted.

# %%
# add the matrices a,b,c together, these will have been passed to the function 
# as standard numpy matrices. Rememeber if you are unsure, just print the 
# elements to see how to access the matrix values.
# there are several ways to do this, anyway you do this is fine
import numpy as np
def add_matrices(a,b,c):
    # initiate the matrix based on the assumption that the matrix is 3x3.
    matrix = np.zeros([3,3])
    ### BEGIN SOLUTION
    # student could use loops, or just the code below.
    matrix = a+b+c
    ### END SOLUTION
    return matrix

## Check your code below using print command
## Random matrices are created here for checking your function
a = np.array([[3,2,1],[1,1,1],[1,1,1]])
b = np.array([[3,2,1],[2,2,2],[2,2,2]])
c = np.array([[3,3,3],[3,3,3],[3,3,3]])
add_matrices(a,b,c)
# Out:
# array([[9, 7, 5],
#        [6, 6, 6],
#        [6, 6, 6]])

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark for the correct solution
a = np.array([[3,2,1],[1,1,1],[1,1,1]])
b = np.array([[3,2,1],[2,2,2],[2,2,2]])
c = np.array([[3,3,3],[3,3,3],[3,3,3]])
d = a+b+c
dd = add_matrices(a,b,c)
assert np.linalg.norm( d-dd ) < 1.e-5
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark for matrix structure returned

a = np.array([[3,2,1],[1,1,1],[1,1,1]])
b = np.array([[3,2,1],[2,2,2],[2,2,2]])
c = np.array([[3,3,3],[3,3,3],[3,3,3]])
d = a+b+c
dd = add_matrices(a,b,c)
dd.shape[0]
dd.shape[1]
assert dd.shape[0] == 3 and dd.shape[1] == 3
### END HIDDEN TESTS

# %% [markdown]
# # Q5:
#
# ### [6 marks]
#
# Compute the code that return the matrix $M = A^T A$ for a given matrix A - the superscript $T$ denoted the transpose. I have started the code for you, which gets the dimension of the matrix, and creates the zero matrix of the correct size. I have also provided some of the loops involved.

# %%
# perform and return the multiplication of $A^TA$
import numpy as np
def multiply_At_A(A):
    # these lines set up the correct dimensions of the returned matrix.
    # the matrix A is of dimension dim1 x dim2 - 
    # the matrix A^T (transpose of A) is dim2 x dim1
    # the matrix (A^T A) is of dimension dim2 x dim2
 
    dim1 = A.shape[0]
    dim2 = A.shape[1]
    matrix = np.zeros([dim2,dim2])
 
    for i in range(dim2):
        for j in range(dim2):
        # complete the final loop to compute matrix[i,j]
 
        ### BEGIN SOLUTION
    
            for k in range(dim1):
                matrix[i,j] = matrix[i,j] + A[k,i]*A[k,j]
             #matrix = np.matmul(np.transpose(A),A)
        ### END SOLUTION
    return matrix

A = np.array([[5,6], [4,6], [4,5]])
print(np.matmul(np.transpose(A), A))
multiply_At_A(A)
# Out:
# [[57 74]
#  [74 97]]
# array([[57., 74.],
#        [74., 97.]])

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark for correct computation
####### You should call the function for marking multiply_At_A(A)
import numpy as np
A = np.array([[3,2,1],[1,1,1],[1,1,1]])
matrix = np.matmul(np.transpose(A),A)
B = multiply_At_A(A)
#print(A)
#print(np.transpose(A))
#print(matrix)
#print(B)
assert np.linalg.norm( matrix - B ) < 1.e-5
A = np.array([[3,2,1,5],[1,1,1,1],[1,1,1,3]])
matrix = np.matmul(np.transpose(A),A)
B = multiply_At_A(A)
assert np.linalg.norm( matrix - B ) < 1.e-5
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark for matrix structure returned
A = np.array([[3,2,1],[1,1,1],[1,1,1]])
A.shape[0]
A.shape[1]
assert A.shape[0] == 3 and A.shape[1] == 3
### END HIDDEN TESTS

# %% [markdown]
# # Q6:
#
# ### [4 marks]
# Write a function to determine the resultant force vector $R$ of the two forces $F_1$ and $F_2$ applied to the bracket, where $\theta_1$ and $\theta_2$. Write $R$ in terms of unit vector along the $x$ and $y$ axis. $R$ must be a vector, for example $R=[R_x, R_y]$. The coordinate system is shown in the figure below:
#
# ![image.png](attachment:ce56156e-3c86-4dbe-a67f-b8daabb181fc.png)

# %%
import numpy as np
import math
from math import * # Import all the math functions from the math library
from numpy import array
# Complete the function given the variables F1, F2, theta1, theta2 and return the value as array
# Hints: Use numpy.array to form the force vector and then add the force vectors toget
# Remember to convert the degree to radian in the calculations and be careful of the sign

def force_vec(F1, F2, theta1, theta2):  
    R=np.array([0,0])
    ### BEGIN SOLUTION
    F1 = np.array([-F1*sin(theta2*pi/180), F1*cos(theta2*pi/180)])
    F2 = np.array([F2*cos(theta1*pi/180), F2*sin(theta1*pi/180)])
    R = F1+F2
    ### END SOLUTION 
    return R #
force_vec(20,25,30,45)
# Out:
# array([ 7.50849947, 26.64213562])

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark for correct computation
#assert force_vec(300, 200, 60, 30)[0] == -49.99999999999994 # Check if the output is an array
### END HIDDEN TESTS

def force_vec(F1, F2, theta1, theta2):  
    R=np.array([0,0])
    # YOUR CODE HERE
    factor=(22/7)/180
    R[0]=-F1*np.sin(theta2*factor)+F2*np.cos(theta1*factor)
    R[1]=F1*np.cos(theta2*factor)+F2*np.sin(theta1*factor)
    return R #
force_vec(99,14,20,24)
# Out:
# array([-27,  95])

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark for correct computation
assert force_vec(300, 200, 60, 30)[1] == 433.0127018922193 # Check if the output is an array
### END HIDDEN TESTS
# Out:
# array([ 15.03837332, 102.65167096])

# %% [markdown]
# # Q7:
#
# ### [9 marks]
#
# A fixed beam is subjected to a uniformly-distributed load with an intensity of  $𝑓= $ 10 N/mm length of  $𝐿= $ 200 mm. Now determine the support reaction forces, internal shear forces and moments, then plot its internal shear force and moment diagram.
#
# ![image.png](attachment:c8277004-fee9-484d-b0ed-12382aded6a4.png)

# %% [markdown]
# ### 1. Define the paramters, use $L$ and $f$ as the variables

# %%
#Program to compute and graph a simply-support beam
#subject to Uniformly Distributed Load

import numpy as np
import matplotlib.pyplot as plt

'You must use the variables name L and f' 
' L: Beam length (mm) '
' f: Load intensity (N/mm)'

### BEGIN SOLUTION
L=200
f=10
### END SOLUTION

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
assert (L==200)
### END HIDDEN TESTS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 3>()
#       1 ## Don't write any code in this box
#       2 ### BEGIN HIDDEN TESTS
# ----> 3 assert (L==200)
#
# NameError: name 'L' is not defined

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
#assert (f==10)
### END HIDDEN TESTS

# %% [markdown]
# ### 2. Find the support reaction forces at $x=0$

# %%
#Reaction force or moment
'You must use the variable names FB_y and FA_y'
'FA_y: Reaction force at the support point A'
'FB_y: Reaction force at the support point B'

### BEGIN SOLUTION
FB_y = -f*L/2   # Force at the support point B
FA_y = -f*L/2   # Force at the support point A
### END SOLUTION

print(FB_y)
# Out:
# -1000.0

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
assert (FB_y==-f*L/2 )
assert (FA_y==-f*L/2 )
### END HIDDEN TESTS

# %% [markdown]
# ### 3. Do the Cut and find the expression for internal force $V$ and moments $M$

# %%
'You must use the variable names f, L, x, V and M'
' L: Beam length (mm) '
' f: Load intensity (N/mm)'
' x: arbitrary poistion along the beam (mm)'
' maxV: Maximum shear force (N) '
' maxM: Maximum internal moment (N*mm)'

### BEGIN SOLUTION
#Shear and Bending arrays
x=np.linspace(0,L)
V=f*L/2-f*x
M=-f*x**2/2 + f*L*x/2
print(V,M)
### END SOLUTION
# Out:
# [ 1000.           959.18367347   918.36734694   877.55102041
#    836.73469388   795.91836735   755.10204082   714.28571429
#    673.46938776   632.65306122   591.83673469   551.02040816
#    510.20408163   469.3877551    428.57142857   387.75510204
#    346.93877551   306.12244898   265.30612245   224.48979592
#    183.67346939   142.85714286   102.04081633    61.2244898
#     20.40816327   -20.40816327   -61.2244898   -102.04081633
#   -142.85714286  -183.67346939  -224.48979592  -265.30612245
#   -306.12244898  -346.93877551  -387.75510204  -428.57142857
#   -469.3877551   -510.20408163  -551.02040816  -591.83673469
#   -632.65306122  -673.46938776  -714.28571429  -755.10204082
#   -795.91836735  -836.73469388  -877.55102041  -918.36734694
#   -959.18367347 -1000.        ] [    0.          3998.33402749  7830.07080383 11495.21032903
#  14993.75260308 18325.69762599 21491.04539775 24489.79591837
#  27321.94918784 29987.50520616 32486.46397334 34818.82548938
# ...

# %% [markdown]
# ### 4. Find the maximum magnitude of internal force and moment

# %%
'Use the variable names maxV and maxM below:'
' maxV: Maximum shear force (N) '
' maxM: Maximum internal moment (N*mm)'

### BEGIN SOLUTION
#Maximum Absolute Values
maxV=max(abs(V))
maxM=max(abs(M))
### END SOLUTION

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
V0=(f*L/2-f*x)
assert (V.any()==V0.any())
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
M0=f*L/2*x-f/2*x**2
assert (M.any()==M0.any())
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
assert (maxV==max(abs(V)))
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
assert (maxM==max(abs(M)))
### END HIDDEN TESTS

# %% [markdown]
# ### 5. Plot the internal shear force and moment diagram
# #### Hint: You can copy the plotting command from the tutorials

# %%
#Diagrams plot
textstr1 = 'min=%.2f (N)'%(maxV)
textstr2 = 'min=%.2f (N*mm)'%(maxM)
props = dict(boxstyle='round', facecolor='white')

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(10, 6))

### Add the plotting command below to draw internal shear force and moment diagram:

### BEGIN SOLUTION
ax1.fill_between(x, 0, V, facecolor='#377EB8', alpha=0.8)
ax1.set_ylabel('Shear force (N)')
ax1.text(0.78, 0.9, textstr1, transform=ax1.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
ax1.set_title('Cantilever Beam Subjected to Gravity Load')
ax1.grid (True)

ax2.fill_between(x, 0, M, facecolor='#55BA87', alpha=0.8)
ax2.set_ylabel('Moment (N*mm)')
ax2.text(0.68, 0.2, textstr2, transform=ax2.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
ax2.grid (True)

plt.show()
### END SOLUTION

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
#assert (fig is not None)
### END HIDDEN TESTS
#Diagrams plot
textstr1 = 'min=%.2f (N)'%(maxV)
textstr2 = 'min=%.2f (N*mm)'%(maxM)
props = dict(boxstyle='round', facecolor='white')

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(10, 6))

### Add the plotting command below to draw internal shear force and moment diagram:
textstr1='max=%.2f(N)'%(maxV)
textstr2= 'max=%.2f(Nmm)'% (maxM)
props= dict(boxstyle='round', facecolor='white')

ax1.fill_between (x,0,V, facecolor= '#377EB8', alpha=0.8)
ax1.set_ylabel('Shear Force (N)')
ax2.set_xlabel ('The distacne from A (mm)')
ax1.text(0.8,0.98,textstr1,transform=ax1.transAxes, fontsize=15,verticalalignment='top',bbox=props)
ax1.set_title('The Simply Supported Beam Subjected to Gravity Load')
ax1.grid(True)

ax2.fill_between(x,0,M, facecolor='#55BA87' ,alpha=0.8)
ax2.set_ylabel('Moment(Nmm)')
ax2.text(0.8,0.98,textstr2, transform=ax2.transAxes, fontsize=15, verticalalignment='top', bbox=props)
ax2.grid(True)

plt.show()
# YOUR CODE HERE

# %% [markdown]
# # Q8:
#
# ### [6 marks]
#
# Define a python function to determine the 2nd moment of area $I_c$ under the parabola, with respect to the **centroidal-axis**. The parabolic curve is defined as $z=ky^2$, where $k=b/h^2$. The centroidal axis has a given distance $d$ with respect to $z$ axis.
#
# **Hints**: Use the parallel axis theorem. Find the 2nd moment of area against $z$ axis first and then use the formula $I_z=I_c+d^2A$ to calculate $I_c$, where $d$ is a given value (no need to derive). Note that this question requires you to derive the equation first.
#
# ![image.png](attachment:9d625fd5-628d-439a-8e70-b61fe66e3872.png)

# %%
# Complete the function given the variables b,h,d and return the value as "Area","Iz" and "Ic"
# This is not about numerical integration, we only need the analytical solution.
# Don't change the predefined content, only fill your code in the region "YOUR CODE"

def SecondMomentArea(b,h,d):
    #Intialise the variables as the return values
    Area=0
    Iz=0
    Ic=0
    
    ### BEGIN SOLUTION
    Area=2*b*h/3
    Iz=2*b*h**3/15
    Ic=Iz-d**2*Area
    ### END SOLUTION
    return Area, Iz, Ic

print(SecondMomentArea(3,7,2))
# Out:
# (14.0, 137.2, 81.19999999999999)

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
assert (SecondMomentArea(3,5,2) == (10.0, 50.0, 10.0)
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
assert (SecondMomentArea(3,6,2) == (12.0, 86.4, 38.400000000000006))
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS 
### Partially correct ###
assert (SecondMomentArea(3,7,2) == (14.0, 137.2, 81.19999999999999))
### [2 marks]
### END HIDDEN TESTS
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       1 ## Don't write any code in this box
#       2 ### BEGIN HIDDEN TESTS
#       3 ### Partially correct ###
# ----> 4 assert (SecondMomentArea(3,4,2) == (4.0, 38.4, 38.4))
#
# AssertionError:

# %% [markdown]
# # Q9:
#
# ### [7 Marks]
#
# We have learned the mid-point and trapezoidal rule for numercial intergration in the tutorials. Now you are asked to implement the Simpson rule, where we approximate the integration of a non-linear curve using piecewise quadratic functions.
#
# Assume $f(x)$  is continuous over  $[a,b]$ .  Let  $[a,b]$  be divided into  $N$  subintervals, each of length  $\Delta x$, with endpoints at  $P={x_0,x_1,x_2,...,x_n,...,x_N}$. Each interval is $\Delta x=(b−a)/N$.
#
# The equation for the Simpson numerical integration rule is derived as:
#
# $\int_a^b f(x) dx \approx \frac{\Delta x}{3} \left[f(x_0)+4 \left(\sum_{n=1, n\  {\text{odd}}}^{N-1}f(x_n)\right)+2 \left(\sum_{n=2, n\  {\text{even}}}^{N-2}f(x_n)\right)+f(x_N)\right].$
#
# Now complete the Python function **InterageSimpson(N, a, b)** below to implement this Simpson rule using the above equation.
#
# The function to be intergrate is $f(x)=2x^3$ (Already defined in the function, no need to change).

# %%
'Complete the function given the variables N,a,b and return the value as "TotalArea".'
"Don't change the predefined content' only fill your code in the region 'YOUR CODE'"

from math import *
def InterageSimpson(N, a, b): # n is the total intervals, a and b is the lower and upper bound respectively
    """Hint: Use loop to add all the values in the above equation and  
    use the if statement to determine whether the value is odd or even"""    
    
    def f(x):
        ## The function f(x)=2*x**3 is defined as below, DON'T CHANGE IT:
        f=2*x**3
        return f 

    value=0   # Initial value
    TotalArea=0  # TotalArea as the final integral value, the area underneath the curve.
    dx=(b-a)/N # delta x, the interval length
    
    # Complete the function by filling your codes below:
    
    ### BEGIN SOLUTION
    value = value + f(a) + f(b) # f(x_0)=a, f(x_n)=b, add the first and last value
    for n in range (1, N): # This will iterate number from x_1 to x_(n-1), as the last value
        xn=a+n*dx # this give the current value
        if (n%2==0):
            value += 2*f(xn)
        elif (n%2==1):
            value += 4*f(xn)
    TotalArea = value*dx/3 # This should be outside the loop
    ### END SOLUTION 
    
    return TotalArea  # Make sure in your solution, you use the same name "TotalArea" for the output

####Check your code by using print command below###

N=100
a=1
b=3

print(InterageSimpson(N, a, b))
# Out:
# 40.00000000000001

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark for correct computation using the simpson rule
N=100
a=1
b=3
assert abs(InterageSimpson(N, a, b)-40.0) < 1.e-5
### END HIDDEN TESTS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 7>()
#       5 a=1
#       6 b=3
# ----> 7 assert abs(InterageSimpson(N, a, b)-40.0) < 1.e-5
#
# NameError: name 'InterageSimpson' is not defined

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark for correct computation using the simpson rule
N=100
a=1
b=3
assert abs(InterageSimpson(N, a, b)-40.00000000000001) < 1.e-5
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark for correct computation using the simpson rule
N=1
a=1
b=3
assert abs(InterageSimpson(N, a, b)-37.333333333333336) < 1.e-5
### END HIDDEN TESTS

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# marks to check there is some number is returned, even if wrong.
N=10
a=1
b=3
assert type(InterageSimpson(N, a, b)) == float or type(InterageSimpson(N, a, b)) == int
### END HIDDEN TESTS

# %%
# Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark for partially-correct, if they use N+1 in the loop, computation using the simpson rule [1 marks]
N=10
a=1
b=3
assert abs(InterageSimpson(N, a, b)-28.292266666666677) < 1.e-5
### END HIDDEN TESTS
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [59], in <cell line: 7>()
#       5 a=1
#       6 b=3
# ----> 7 assert abs(InterageSimpson(N, a, b)-28.292266666666677) < 1.e-5
#
# AssertionError:

# %%
## Don't write any code in this box
### BEGIN HIDDEN TESTS
# mark for mid-point rule [1 marks]
N=10
a=1
b=3
assert abs(InterageSimpson(N, a, b)-39.92) < 1.e-5
### END HIDDEN TESTS
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [60], in <cell line: 7>()
#       5 a=1
#       6 b=3
# ----> 7 assert abs(InterageSimpson(N, a, b)-39.92) < 1.e-5
#
# AssertionError:

# %% [markdown]
# ### DON'T ADD OR DELETE ANY CODING BOXES
